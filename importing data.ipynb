# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("netflix_titles_2021.csv")

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.sample()
# Out:
#      show_id     type                   title director  \
# 8189   s8190  TV Show  The Andy Griffith Show      NaN
#
#                                                    cast        country  \
# 8189  Andy Griffith, Ron Howard, Don Knotts, Frances...  United States
#
#          date_added  release_year rating   duration  \
# 8189   July 1, 2017          1967   TV-G  8 Seasons
#
#                            listed_in  \
# 8189  Classic & Cult TV, TV Comedies
#
#                                             description
# 8189  Homespun humor and easygoing Sheriff Andy Tayl...

# %%
df.sample(20)
# Out:
#      show_id     type                                       title  \
# 7844   s7845    Movie                                    Red Dawn
# 2518   s2519  TV Show                                        Iris
# 6327   s6328    Movie                            Black Snake Moan
# 7243   s7244    Movie                                   Kuppivala
# 1528   s1529  TV Show                                      Run On
# 8789   s8790    Movie                         You Changed My Life
# 7423   s7424    Movie                                    Max Rose
# 4858   s4859    Movie  Katt Williams: American Hustle (The Movie)
# 7397   s7398    Movie                           Manhattan Romance
# 4404   s4405    Movie                                 Outlaw King
# 5106   s5107    Movie               Bibi & Tina: Tohuwabohu Total
# 723     s724  TV Show                The American Bible Challenge
# 6328   s6329    Movie                                  Black Snow
# ...

# %%
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
df.loc[2000:2050]
# Out:
#      show_id     type                                   title  \
# 2000   s2001    Movie               Michael McIntyre: Showman
# 2001   s2002    Movie                   Raising Victor Vargas
# 2002   s2003  TV Show                         Taco Chronicles
# 2003   s2004    Movie                            The Smurfs 2
# 2004   s2005    Movie                     Wish Upon a Unicorn
# 2005   s2006    Movie                       Lara and the Beat
# 2006   s2007  TV Show                                   Buddi
# 2007   s2008    Movie                              Dad Wanted
# 2008   s2009  TV Show                         Family Business
# 2009   s2010  TV Show                             Girlfriends
# 2010   s2011    Movie              How to Train Your Dragon 2
# 2011   s2012    Movie                             Pets United
# 2012   s2013  TV Show                             The Barrier
# 2013   s2014  TV Show                             The Duchess
# ...

# %%
df.loc[200]
# Out:
# show_id                                                      s201
# type                                                        Movie
# title                                             Krishna Cottage
# director                                            Santram Varma
# cast            Sohail Khan, Isha Koppikar, Natassha, Rati Agn...
# country                                                     India
# date_added                                        August 27, 2021
# release_year                                                 2004
# rating                                                      TV-14
# duration                                                  124 min
# listed_in       Action & Adventure, Horror Movies, Internation...
# description     True love is put to the test when another woma...
# Name: 200, dtype: object

# %%
df1=pd.read_json("CO2.json")
df1
# Out:
#                                                fields
# 0   {'name': 'Country', 'title': 'Country name', '...
# 1   {'name': 'ISO 3166-1 alpha-3', 'title': 'ISO c...
# 2   {'name': 'Year', 'title': 'Year', 'note': 'In ...
# 3   {'name': 'Total', 'title': 'Total fossil CO2 e...
# 4   {'name': 'Coal', 'title': 'Fossil CO2 emission...
# 5   {'name': 'Oil', 'title': 'Fossil CO2 emissions...
# 6   {'name': 'Gas', 'title': 'Fossil CO2 emissions...
# 7   {'name': 'Cement', 'title': 'Fossil CO2 emissi...
# 8   {'name': 'Flaring', 'title': 'Fossil CO2 emiss...
# 9   {'name': 'Other', 'title': 'Fossil CO2 emissio...
# 10  {'name': 'Per Capita', 'title': 'Per capita fo...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   fields  11 non-null     object
# dtypes: object(1)
# memory usage: 216.0+ bytes

# %%
df1.tail()
# Out:
#                                                fields
# 6   {'name': 'Gas', 'title': 'Fossil CO2 emissions...
# 7   {'name': 'Cement', 'title': 'Fossil CO2 emissi...
# 8   {'name': 'Flaring', 'title': 'Fossil CO2 emiss...
# 9   {'name': 'Other', 'title': 'Fossil CO2 emissio...
# 10  {'name': 'Per Capita', 'title': 'Per capita fo...

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df2=pd.read_excel("Employee Sample Data.xlsx")
df2.head()
# Out:
#      EEID        Full Name                 Job Title Department  \
# 0  E02387      Emily Davis                Sr. Manger         IT
# 1  E04105    Theodore Dinh       Technical Architect         IT
# 2  E02572     Luna Sanders                  Director    Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager         IT
# 4  E01639        Austin Vo               Sr. Analyst    Finance
#
#             Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black   55 2016-04-08         141604
# 1           Manufacturing    Male      Asian   59 1997-11-29          99975
# 2     Speciality Products  Female  Caucasian   50 2006-10-26         163099
# 3           Manufacturing  Female  Caucasian   26 2019-09-27          84913
# 4           Manufacturing    Male      Asian   55 1995-11-20          95409
#
#    Bonus %        Country       City  Exit Date
# 0     0.15  United States    Seattle 2021-10-16
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   EEID           1000 non-null   object
#  1   Full Name      1000 non-null   object
#  2   Job Title      1000 non-null   object
#  3   Department     1000 non-null   object
#  4   Business Unit  1000 non-null   object
#  5   Gender         1000 non-null   object
#  6   Ethnicity      1000 non-null   object
#  7   Age            1000 non-null   int64
#  8   Hire Date      1000 non-null   datetime64[ns]
#  9   Annual Salary  1000 non-null   int64
#  10  Bonus %        1000 non-null   float64
#  11  Country        1000 non-null   object
#  12  City           1000 non-null   object
#  13  Exit Date      85 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(2), object(9)
# memory usage: 109.5+ KB

# %%
df2.tail()
# Out:
#        EEID     Full Name       Job Title  Department        Business Unit  \
# 995  E03094  Wesley Young     Sr. Analyst   Marketing  Speciality Products
# 996  E01909  Lillian Khan         Analyst     Finance  Speciality Products
# 997  E04398   Oliver Yang        Director   Marketing  Speciality Products
# 998  E02521   Lily Nguyen     Sr. Analyst     Finance  Speciality Products
# 999  E03545   Sofia Cheng  Vice President  Accounting            Corporate
#
#      Gender  Ethnicity  Age  Hire Date  Annual Salary  Bonus %        Country  \
# 995    Male  Caucasian   33 2016-09-18          98427     0.00  United States
# 996  Female      Asian   44 2010-05-31          47387     0.00          China
# 997    Male      Asian   31 2019-06-10         176710     0.15  United States
# 998  Female      Asian   33 2012-01-28          95960     0.00          China
# 999  Female      Asian   63 2020-07-26         216195     0.31  United States
#
#          City  Exit Date
# ...

# %%
df2.describe()
# Out:
#                Age  Annual Salary      Bonus %
# count  1000.000000    1000.000000  1000.000000
# mean     44.382000  113217.365000     0.088660
# std      11.246981   53545.985644     0.117856
# min      25.000000   40063.000000     0.000000
# 25%      35.000000   71430.250000     0.000000
# 50%      45.000000   96557.000000     0.000000
# 75%      54.000000  150782.250000     0.150000
# max      65.000000  258498.000000     0.400000
