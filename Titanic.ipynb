# %% [markdown]
#    # Titanic Data Analysis

# %%
import pandas as pd

# %%
df=pd.read_csv('./titanic.csv.csv')

# %% [markdown]
# ## Head

# %%
df.head(52)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1       0.0       3
# 1             2       1.0       1
# 2             3       1.0       3
# 3             4       1.0       1
# 4             5       0.0       3
# 5             6       0.0       3
# 6             7       0.0       1
# 7             8       0.0       3
# 8             9       1.0       3
# 9            10       1.0       2
# 10           11       1.0       3
# 11           12       1.0       1
# 12           13       0.0       3
# 13           14       0.0       3
# 14           15       0.0       3
# 15           16       1.0       2
# 16           17       0.0       3
# 17           18       1.0       2
# 18           19       0.0       3
# 19           20       1.0       3
# 20           21       0.0       2
# 21           22       1.0       2
# 22           23       1.0       3
# 23           24       1.0       1
# 24           25       0.0       3
# 25           26       1.0       3
# ...

# %%
df.tail(5)
# Out:
#       PassengerId  Survived  Pclass                          Name     Sex  \
# 1304         1305       NaN       3            Spector, Mr. Woolf    male
# 1305         1306       NaN       1  Oliva y Ocana, Dona. Fermina  female
# 1306         1307       NaN       3  Saether, Mr. Simon Sivertsen    male
# 1307         1308       NaN       3           Ware, Mr. Frederick    male
# 1308         1309       NaN       3      Peter, Master. Michael J    male
#
#        Age  SibSp  Parch              Ticket      Fare  ... Embarked  WikiId  \
# 1304   NaN      0      0           A.5. 3236    8.0500  ...        S  1227.0
# 1305  39.0      0      0            PC 17758  108.9000  ...        C   229.0
# 1306  38.5      0      0  SOTON/O.Q. 3101262    7.2500  ...        S  1169.0
# 1307   NaN      0      0              359309    8.0500  ...        S  1289.0
# 1308   NaN      1      1                2668   22.3583  ...        C   702.0
#
#                                  Name_wiki Age_wiki  \
# ...

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass                      Name   Sex   Age  \
# 482          483       0.0       3  Rouse, Mr. Richard Henry  male  50.0
#
#      SibSp  Parch    Ticket  Fare  ... Embarked  WikiId  \
# 482      0      0  A/5 3594  8.05  ...        S  1165.0
#
#                     Name_wiki Age_wiki                      Hometown  \
# 482  Rouse, Mr. Richard Henry     50.0  Sittingbourne, Kent, England
#
#          Boarded          Destination Lifeboat Body Class
# 482  Southampton  Cleveland, Ohio, US      NaN  NaN   3.0
#
# [1 rows x 21 columns]

# %%
df.sample(10)
# Out:
#       PassengerId  Survived  Pclass  \
# 386           387       0.0       3
# 1175         1176       NaN       3
# 1156         1157       NaN       3
# 1154         1155       NaN       3
# 721           722       0.0       3
# 1290         1291       NaN       3
# 803           804       1.0       3
# 1231         1232       NaN       2
# 781           782       1.0       1
# 999          1000       NaN       3
#
#                                            Name     Sex    Age  SibSp  Parch  \
# 386             Goodwin, Master. Sidney Leonard    male   1.00      5      2
# 1175                Rosblom, Miss. Salli Helena  female   2.00      1      1
# 1156                      Lyntakoff, Mr. Stanko    male    NaN      0      0
# 1154               Klasen, Miss. Gertrud Emilia  female   1.00      1      1
# 721                   Jensen, Mr. Svend Lauritz    male  17.00      1      0
# 1290                   Conlon, Mr. Thomas Henry    male  31.00      0      0
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.881138     0.498854
# std     378.020061    0.486592     0.837836    14.413493     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    21.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.000000     0.000000
# 75%     982.000000    1.000000     3.000000    39.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare       WikiId     Age_wiki        Class
# count  1309.000000  1308.000000  1304.000000  1302.000000  1304.000000
# mean      0.385027    33.295479   658.534509    29.415829     2.291411
# std       0.865560    51.758668   380.377373    13.758954     0.840852
# ...

# %%
df.describe().T
# Out:
#               count        mean         std   min       25%       50%  \
# PassengerId  1309.0  655.000000  378.020061  1.00  328.0000  655.0000
# Survived      891.0    0.383838    0.486592  0.00    0.0000    0.0000
# Pclass       1309.0    2.294882    0.837836  1.00    2.0000    3.0000
# Age          1046.0   29.881138   14.413493  0.17   21.0000   28.0000
# SibSp        1309.0    0.498854    1.041658  0.00    0.0000    0.0000
# Parch        1309.0    0.385027    0.865560  0.00    0.0000    0.0000
# Fare         1308.0   33.295479   51.758668  0.00    7.8958   14.4542
# WikiId       1304.0  658.534509  380.377373  1.00  326.7500  661.5000
# Age_wiki     1302.0   29.415829   13.758954  0.17   21.0000   28.0000
# Class        1304.0    2.291411    0.840852  1.00    1.7500    3.0000
#
#                  75%        max
# PassengerId  982.000  1309.0000
# Survived       1.000     1.0000
# Pclass         3.000     3.0000
# Age           39.000    80.0000
# ...

# %%
df.shape
# Out:
# (1309, 21)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'WikiId', 'Name_wiki',
#        'Age_wiki', 'Hometown', 'Boarded', 'Destination', 'Lifeboat', 'Body',
#        'Class'],
#       dtype='object')
